# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
music_data = pd.read_csv('wikipedia_scraper.csv', encoding='ISO-8859-1')

# %%
music_data.head()
# Out:
#   rank                      title               artist  year
# 0    1  Theme from A Summer Place          Percy Faith  1960
# 1    2           He'll Have to Go           Jim Reeves  1960
# 2    3              Cathy's Clown  The Everly Brothers  1960
# 3    4               Running Bear       Johnny Preston  1960
# 4    5                 Teen Angel         Mark Dinning  1960

# %%
music_data.loc[0]
# Out:
# rank                              1
# title     Theme from A Summer Place
# artist                  Percy Faith
# year                           1960
# Name: 0, dtype: object

# %%
file = 'Spotify.txt'# replace this with the path and file name you use
with open(file,'r') as f: 
    f = f.read().splitlines()
    cid = f[0]
    secret = f[1]
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# Test

# %%
track = music_data.title[0]
artist = music_data.artist[0]

# %%
artist,track
# Out:
# ('Percy Faith', 'Theme from A Summer Place')

# %%
track_id = sp.search(q='artist:' + artist + ' track:' + track, type='track')
track_id
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3APercy+Faith+track%3ATheme+from+A+Summer+Place&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#        'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#        'id': '24DQLSng7bKZD4GXLIaQbv',
#        'name': 'Percy Faith & His Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0XLV6vIukKpejiSTAaSPPi'},
#      'href': 'https://api.spotify.com/v1/albums/0XLV6vIukKpejiSTAaSPPi',
#      'id': '0XLV6vIukKpejiSTAaSPPi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ae5534556d63b3935e7532e0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ae5534556d63b3935e7532e0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ae5534556d63b3935e7532e0',
#        'width': 64}],
#      'name': '16 Most Requested Songs',
#      'release_date': '1989-06-13',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:0XLV6vIukKpejiSTAaSPPi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#       'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#       'id': '24DQLSng7bKZD4GXLIaQbv',
#       'name': 'Percy Faith & His Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 142693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19915945'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6zwvB879PJSpTyFcg2wwnL'},
#     'href': 'https://api.spotify.com/v1/tracks/6zwvB879PJSpTyFcg2wwnL',
#     'id': '6zwvB879PJSpTyFcg2wwnL',
#     'is_local': False,
#     'name': 'The Theme from "A Summer Place"',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8312667a50c3908c5aea84554eefb2812159d2fb?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:6zwvB879PJSpTyFcg2wwnL'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#        'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#        'id': '24DQLSng7bKZD4GXLIaQbv',
#        'name': 'Percy Faith & His Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4AdlSv0lu4ybv2PXv7Moma'},
#      'href': 'https://api.spotify.com/v1/albums/4AdlSv0lu4ybv2PXv7Moma',
#      'id': '4AdlSv0lu4ybv2PXv7Moma',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273305d0d7ce3dbf3f54508af6d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02305d0d7ce3dbf3f54508af6d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851305d0d7ce3dbf3f54508af6d',
#        'width': 64}],
#      'name': "Percy Faith'S Greatest Hits",
#      'release_date': '1953',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4AdlSv0lu4ybv2PXv7Moma'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#       'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#       'id': '24DQLSng7bKZD4GXLIaQbv',
#       'name': 'Percy Faith & His Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 144893,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM19915912'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2kKL5kk4On8YRSKWDgXWMX'},
#     'href': 'https://api.spotify.com/v1/tracks/2kKL5kk4On8YRSKWDgXWMX',
#     'id': '2kKL5kk4On8YRSKWDgXWMX',
#     'is_local': False,
#     'name': 'The Theme from "A Summer Place" - Single Version',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/df5fb79fbf462e34529670d8e023fe6650087f3f?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2kKL5kk4On8YRSKWDgXWMX'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3AouBQaR0dUkTGM7qBAUYv'},
#      'href': 'https://api.spotify.com/v1/albums/3AouBQaR0dUkTGM7qBAUYv',
#      'id': '3AouBQaR0dUkTGM7qBAUYv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739415176d9fb44027ae0593a6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029415176d9fb44027ae0593a6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519415176d9fb44027ae0593a6',
#        'width': 64}],
#      'name': 'Love Themes: A Special Soundtrack Collection for Lovers',
#      'release_date': '2013-02-12',
#      'release_date_precision': 'day',
#      'total_tracks': 50,
#      'type': 'album',
#      'uri': 'spotify:album:3AouBQaR0dUkTGM7qBAUYv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5DKskeikqcvDDJKxjlYWqC'},
#       'href': 'https://api.spotify.com/v1/artists/5DKskeikqcvDDJKxjlYWqC',
#       'id': '5DKskeikqcvDDJKxjlYWqC',
#       'name': 'Percy Faith Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:5DKskeikqcvDDJKxjlYWqC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 146546,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6V81567348'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5V9rUjZJfktI9EyHLHp40M'},
#     'href': 'https://api.spotify.com/v1/tracks/5V9rUjZJfktI9EyHLHp40M',
#     'id': '5V9rUjZJfktI9EyHLHp40M',
#     'is_local': False,
#     'name': 'A Summer Place - Theme from A Summer Place',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c4cfb3def4bc92b8eec9feb5270ee975681615ef?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5V9rUjZJfktI9EyHLHp40M'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#        'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#        'id': '24DQLSng7bKZD4GXLIaQbv',
#        'name': 'Percy Faith & His Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5BbIjj8zjYtFoE94MD0K78'},
#      'href': 'https://api.spotify.com/v1/albums/5BbIjj8zjYtFoE94MD0K78',
#      'id': '5BbIjj8zjYtFoE94MD0K78',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cec78bc00fbb4872d0e0919e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cec78bc00fbb4872d0e0919e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cec78bc00fbb4872d0e0919e',
#        'width': 64}],
#      'name': 'All My Love Bolero (Instrumental)',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 24,
#      'type': 'album',
#      'uri': 'spotify:album:5BbIjj8zjYtFoE94MD0K78'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#       'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#       'id': '24DQLSng7bKZD4GXLIaQbv',
#       'name': 'Percy Faith & His Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 144400,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR2X41919028'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Beh9tOBoHqyo0pAzD7WnC'},
#     'href': 'https://api.spotify.com/v1/tracks/6Beh9tOBoHqyo0pAzD7WnC',
#     'id': '6Beh9tOBoHqyo0pAzD7WnC',
#     'is_local': False,
#     'name': 'Theme from a Summer Place',
#     'popularity': 13,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6cc341f67f675cd761a0e08ee56ce5c790739f39?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6Beh9tOBoHqyo0pAzD7WnC'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#        'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#        'id': '24DQLSng7bKZD4GXLIaQbv',
#        'name': 'Percy Faith & His Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0dA8Iq9534j5yb7b4HA6Li'},
#      'href': 'https://api.spotify.com/v1/albums/0dA8Iq9534j5yb7b4HA6Li',
#      'id': '0dA8Iq9534j5yb7b4HA6Li',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27345310f3d3f0164105992c070',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0245310f3d3f0164105992c070',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485145310f3d3f0164105992c070',
#        'width': 64}],
#      'name': 'Tara\'s Theme from "Gone With The Wind" and Other Movie Themes',
#      'release_date': '1961',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0dA8Iq9534j5yb7b4HA6Li'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1s8NQxAEct8j8JZT05CIUu'},
#       'href': 'https://api.spotify.com/v1/artists/1s8NQxAEct8j8JZT05CIUu',
#       'id': '1s8NQxAEct8j8JZT05CIUu',
#       'name': 'Percy Faith & His Orchestra & Chorus',
#       'type': 'artist',
#       'uri': 'spotify:artist:1s8NQxAEct8j8JZT05CIUu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 142920,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10204685'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/77laaqPYPavCt1Tsxn4tbK'},
#     'href': 'https://api.spotify.com/v1/tracks/77laaqPYPavCt1Tsxn4tbK',
#     'id': '77laaqPYPavCt1Tsxn4tbK',
#     'is_local': False,
#     'name': 'Theme from "A Summer Place"',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4888841662233c97c3e89929e7ebe6c5cb32741f?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:77laaqPYPavCt1Tsxn4tbK'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1pHqiAEWGbDKIyahtxd5Wj'},
#      'href': 'https://api.spotify.com/v1/albums/1pHqiAEWGbDKIyahtxd5Wj',
#      'id': '1pHqiAEWGbDKIyahtxd5Wj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27343644abdff7faa3c6738973f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0243644abdff7faa3c6738973f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485143644abdff7faa3c6738973f',
#        'width': 64}],
#      'name': 'Love in Movies: A Romantic Collection from Great Cinema Classics',
#      'release_date': '2013-02-12',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:1pHqiAEWGbDKIyahtxd5Wj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6unIK8JFrGemCge3NIUDKE'},
#       'href': 'https://api.spotify.com/v1/artists/6unIK8JFrGemCge3NIUDKE',
#       'id': '6unIK8JFrGemCge3NIUDKE',
#       'name': 'Percy Faith',
#       'type': 'artist',
#       'uri': 'spotify:artist:6unIK8JFrGemCge3NIUDKE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 142817,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6V81569042'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6E4UcJwsCLWZy5UNhtPKDc'},
#     'href': 'https://api.spotify.com/v1/tracks/6E4UcJwsCLWZy5UNhtPKDc',
#     'id': '6E4UcJwsCLWZy5UNhtPKDc',
#     'is_local': False,
#     'name': 'A Summer Place, Scandalo al sole - Theme from A Summer Place',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ace46edf992a68721d3d09cc3629d77448e5c45a?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:6E4UcJwsCLWZy5UNhtPKDc'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#        'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#        'id': '24DQLSng7bKZD4GXLIaQbv',
#        'name': 'Percy Faith & His Orchestra',
#        'type': 'artist',
#        'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/205gksgDHwJUOuJ7GV4MKu'},
#      'href': 'https://api.spotify.com/v1/albums/205gksgDHwJUOuJ7GV4MKu',
#      'id': '205gksgDHwJUOuJ7GV4MKu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27305b9a5d1bec8216875f01ccf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0205b9a5d1bec8216875f01ccf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485105b9a5d1bec8216875f01ccf',
#        'width': 64}],
#      'name': 'The Essential Percy Faith - The Instrumental Recordings',
#      'release_date': '2018-07-13',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:205gksgDHwJUOuJ7GV4MKu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#       'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#       'id': '24DQLSng7bKZD4GXLIaQbv',
#       'name': 'Percy Faith & His Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 142386,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM15900951'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7rlH1Eb2JHnmuc74WOdBym'},
#     'href': 'https://api.spotify.com/v1/tracks/7rlH1Eb2JHnmuc74WOdBym',
#     'id': '7rlH1Eb2JHnmuc74WOdBym',
#     'is_local': False,
#     'name': 'Theme from "A Summer Place"',
#     'popularity': 16,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0dffdc9572b7e5be089563dfbb2d9f3379c98ad1?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7rlH1Eb2JHnmuc74WOdBym'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/28oPljw32I8H4LWfdQ2z7z'},
#      'href': 'https://api.spotify.com/v1/albums/28oPljw32I8H4LWfdQ2z7z',
#      'id': '28oPljw32I8H4LWfdQ2z7z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736694d49395fd6b69b2221faa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026694d49395fd6b69b2221faa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516694d49395fd6b69b2221faa',
#        'width': 64}],
#      'name': 'The Graduate - Music From The Broadway Comedy',
#      'release_date': '1959',
#      'release_date_precision': 'year',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:28oPljw32I8H4LWfdQ2z7z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#       'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#       'id': '24DQLSng7bKZD4GXLIaQbv',
#       'name': 'Percy Faith & His Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 144306,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM15900951'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/03VI1k560HUYTOZo2d2xpZ'},
#     'href': 'https://api.spotify.com/v1/tracks/03VI1k560HUYTOZo2d2xpZ',
#     'id': '03VI1k560HUYTOZo2d2xpZ',
#     'is_local': False,
#     'name': 'Theme from "A Summer Place"',
#     'popularity': 20,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1323c00f240d0b5650d24fca449d9514cacf59b8?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:03VI1k560HUYTOZo2d2xpZ'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5sAgbiWPDTAN45IgvikLd2'},
#      'href': 'https://api.spotify.com/v1/albums/5sAgbiWPDTAN45IgvikLd2',
#      'id': '5sAgbiWPDTAN45IgvikLd2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734e3c395dbf86305d74c4250b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024e3c395dbf86305d74c4250b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514e3c395dbf86305d74c4250b',
#        'width': 64}],
#      'name': 'Summer Holiday Hits: Live For the Sun',
#      'release_date': '2017-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5sAgbiWPDTAN45IgvikLd2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6unIK8JFrGemCge3NIUDKE'},
#       'href': 'https://api.spotify.com/v1/artists/6unIK8JFrGemCge3NIUDKE',
#       'id': '6unIK8JFrGemCge3NIUDKE',
#       'name': 'Percy Faith',
#       'type': 'artist',
#       'uri': 'spotify:artist:6unIK8JFrGemCge3NIUDKE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 140372,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBT21606577'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4KA1HUElsp9PSAvGlHDQ39'},
#     'href': 'https://api.spotify.com/v1/tracks/4KA1HUElsp9PSAvGlHDQ39',
#     'id': '4KA1HUElsp9PSAvGlHDQ39',
#     'is_local': False,
#     'name': 'Theme from a Summer Place',
#     'popularity': 8,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dc64078d57756df1bc1063e52fc3c8b28a31d14a?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4KA1HUElsp9PSAvGlHDQ39'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6unIK8JFrGemCge3NIUDKE'},
#        'href': 'https://api.spotify.com/v1/artists/6unIK8JFrGemCge3NIUDKE',
#        'id': '6unIK8JFrGemCge3NIUDKE',
#        'name': 'Percy Faith',
#        'type': 'artist',
#        'uri': 'spotify:artist:6unIK8JFrGemCge3NIUDKE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0bjMOcRhFAGJn5WfAnCeba'},
#      'href': 'https://api.spotify.com/v1/albums/0bjMOcRhFAGJn5WfAnCeba',
#      'id': '0bjMOcRhFAGJn5WfAnCeba',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27314a927e0f70385e3c910ef48',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0214a927e0f70385e3c910ef48',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485114a927e0f70385e3c910ef48',
#        'width': 64}],
#      'name': 'The Essential Percy Faith',
#      'release_date': '2014-04-18',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:0bjMOcRhFAGJn5WfAnCeba'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/24DQLSng7bKZD4GXLIaQbv'},
#       'href': 'https://api.spotify.com/v1/artists/24DQLSng7bKZD4GXLIaQbv',
#       'id': '24DQLSng7bKZD4GXLIaQbv',
#       'name': 'Percy Faith & His Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:24DQLSng7bKZD4GXLIaQbv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 141813,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM15900951'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0u2SAXezijSxFrCf7h3e6s'},
#     'href': 'https://api.spotify.com/v1/tracks/0u2SAXezijSxFrCf7h3e6s',
#     'id': '0u2SAXezijSxFrCf7h3e6s',
#     'is_local': False,
#     'name': 'Theme from "A Summer Place"',
#     'popularity': 11,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1692d238359c4ed33cdc43dc830cb4187f912599?cid=2e54e7e2135644648a3aeaeabdb80336',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:0u2SAXezijSxFrCf7h3e6s'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=artist%3APercy+Faith+track%3ATheme+from+A+Summer+Place&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 17}}

# %%
id_ = track_id['tracks']['items'][0]['id']
popularity = track_id['tracks']['items'][0]['popularity']

# %%
id_,popularity
# Out:
# ('6zwvB879PJSpTyFcg2wwnL', 57)

# %%
def get_spotify_data(dataframe):
    """
    Takes a dataframe as input.
    Returns a list of track ids and a list of popularity scores from the Spotify API. 
    """
    from numpy import nan # we import np.nan to handle empty queries 
    track_ids = []
    popularities = []
    for [artist, song] in list(zip(dataframe['artist'], dataframe['title'])):
        try:
            song_data = sp.search(q='artist:' + artist + ' track:' + song, type='track')
            track_id = song_data['tracks']['items'][0]['id']
            popularity = song_data['tracks']['items'][0]['popularity']
            track_ids.append(track_id)
            popularities.append(popularity)
        except:
            track_ids.append(nan)
            popularities.append(nan)
    return track_ids, popularities
track_ids, popularities = get_spotify_data(music_data)
music_data['Spotify id'] = track_ids
music_data['Popularity'] = popularities
music_data
# Out:
#      rank                      title                            artist  year  \
# 0       1  Theme from A Summer Place                       Percy Faith  1960
# 1       2           He'll Have to Go                        Jim Reeves  1960
# 2       3              Cathy's Clown               The Everly Brothers  1960
# 3       4               Running Bear                    Johnny Preston  1960
# 4       5                 Teen Angel                      Mark Dinning  1960
# ...   ...                        ...                               ...   ...
# 6096   96      More Than My Hometown                     Morgan Wallen  2020
# 6097   97              Lovin' on You                        Luke Combs  2020
# 6098   98                   Said Sum                      Moneybagg Yo  2020
# 6099   99                      Slide               H.E.R. featuring YG  2020
# 6100  100               Walk Em Down  NLE Choppa featuring Roddy Ricch  2020
#
#                   Spotify id  Popularity
# 0     6zwvB879PJSpTyFcg2wwnL        57.0
# 1     7dDE59NX0n466e705E8Itz        18.0
# 2     1MA9StLzlFftLbuqOmoWij        52.0
# 3     1RYznli2VNO7FCbW1Hq4KM        39.0
# 4     36NPEs4S7ik50NrlzaqoIJ        31.0
# ...                      ...         ...
# 6096  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099                     NaN         NaN
# 6100                     NaN         NaN
#
# [6101 rows x 6 columns]

# %%
music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6101 entries, 0 to 6100
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        6101 non-null   object
#  1   title       6101 non-null   object
#  2   artist      6101 non-null   object
#  3   year        6101 non-null   int64
#  4   Spotify id  4950 non-null   object
#  5   Popularity  4950 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 286.1+ KB

# %%
music_data['Spotify id'].isnull().sum()
# Out:
# 1151

# %% [markdown]
# There are a lot of songs without a Spotify id. One reason why the Spotify ids for these songs were not extracted is because the get_spotify_data function does not recognize artists in the artist column that have multiple artists. These data contain strings such as "featuring", "and", and "&", so we'll split the artists into multiple columns that contain the primary artist and featured artists.

# %%
# the last two songs are good examples where spotify ids weren't extracted
music_data.tail()
# Out:
#      rank                  title                            artist  year  \
# 6096   96  More Than My Hometown                     Morgan Wallen  2020
# 6097   97          Lovin' on You                        Luke Combs  2020
# 6098   98               Said Sum                      Moneybagg Yo  2020
# 6099   99                  Slide               H.E.R. featuring YG  2020
# 6100  100           Walk Em Down  NLE Choppa featuring Roddy Ricch  2020
#
#                   Spotify id  Popularity
# 6096  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099                     NaN         NaN
# 6100                     NaN         NaN

# %%
artist_list = []
feat_artist_list = []

def split_artists(dataframe):
    '''
    Check if the artist column has featured artists, then split artists into lists
    '''
    for index, row in dataframe.iterrows():
        if(pd.isnull(row['Spotify id'])):
            artist_list.append(row['artist'].replace(" & ", "_" ).replace(" featuring ","_").replace(" and ","_").replace(", ","_").replace(" with ","_").split("_")[0])
            
            #there may or not be a featured artist, so check if this is true
            try:
                feat_artist_list.append(row['artist'].replace(" & ", "_" ).replace(" featuring ","_").replace(" and ","_").replace(", ","_").replace(" with ","_").split("_")[1])
            except:
                feat_artist_list.append("None")
        else:
            artist_list.append(row['artist'])
            feat_artist_list.append("None")

# %%
split_artists(music_data)

# %%
artist_list[-5:]
# Out:
# ['Morgan Wallen', 'Luke Combs', 'Moneybagg Yo', 'H.E.R.', 'NLE Choppa']

# %%
feat_artist_list[-5:]
# Out:
# ['None', 'None', 'None', 'YG', 'Roddy Ricch']

# %%
music_data
# Out:
#      rank                      title                            artist  year  \
# 0       1  Theme from A Summer Place                       Percy Faith  1960
# 1       2           He'll Have to Go                        Jim Reeves  1960
# 2       3              Cathy's Clown               The Everly Brothers  1960
# 3       4               Running Bear                    Johnny Preston  1960
# 4       5                 Teen Angel                      Mark Dinning  1960
# ...   ...                        ...                               ...   ...
# 6096   96      More Than My Hometown                     Morgan Wallen  2020
# 6097   97              Lovin' on You                        Luke Combs  2020
# 6098   98                   Said Sum                      Moneybagg Yo  2020
# 6099   99                      Slide               H.E.R. featuring YG  2020
# 6100  100               Walk Em Down  NLE Choppa featuring Roddy Ricch  2020
#
#                   Spotify id  Popularity
# 0     6zwvB879PJSpTyFcg2wwnL        57.0
# 1     7dDE59NX0n466e705E8Itz        18.0
# 2     1MA9StLzlFftLbuqOmoWij        52.0
# 3     1RYznli2VNO7FCbW1Hq4KM        39.0
# 4     36NPEs4S7ik50NrlzaqoIJ        31.0
# ...                      ...         ...
# 6096  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099                     NaN         NaN
# 6100                     NaN         NaN
#
# [6101 rows x 6 columns]

# %%
music_data["artist"] = artist_list

# %%
music_data["other artists"] = feat_artist_list

# %%
music_data
# Out:
#      rank                      title               artist  year  \
# 0       1  Theme from A Summer Place          Percy Faith  1960
# 1       2           He'll Have to Go           Jim Reeves  1960
# 2       3              Cathy's Clown  The Everly Brothers  1960
# 3       4               Running Bear       Johnny Preston  1960
# 4       5                 Teen Angel         Mark Dinning  1960
# ...   ...                        ...                  ...   ...
# 6096   96      More Than My Hometown        Morgan Wallen  2020
# 6097   97              Lovin' on You           Luke Combs  2020
# 6098   98                   Said Sum         Moneybagg Yo  2020
# 6099   99                      Slide               H.E.R.  2020
# 6100  100               Walk Em Down           NLE Choppa  2020
#
#                   Spotify id  Popularity other artists
# 0     6zwvB879PJSpTyFcg2wwnL        57.0          None
# 1     7dDE59NX0n466e705E8Itz        18.0          None
# 2     1MA9StLzlFftLbuqOmoWij        52.0          None
# 3     1RYznli2VNO7FCbW1Hq4KM        39.0          None
# 4     36NPEs4S7ik50NrlzaqoIJ        31.0          None
# ...                      ...         ...           ...
# 6096  0eBXyY4SatzpE7opnzgXvz        83.0          None
# 6097  0nYvjcSlCgjcwogQAwIwNp        76.0          None
# 6098  3sKz6Sd72K0ofPWcJPPk6H        75.0          None
# 6099                     NaN         NaN            YG
# 6100                     NaN         NaN   Roddy Ricch
#
# [6101 rows x 7 columns]

# %%
music_data = music_data[['rank', 'title', 'artist', 'other artists', 'year', 'Spotify id', 'Popularity']]

# %%
music_data
# Out:
#      rank                      title               artist other artists  year  \
# 0       1  Theme from A Summer Place          Percy Faith          None  1960
# 1       2           He'll Have to Go           Jim Reeves          None  1960
# 2       3              Cathy's Clown  The Everly Brothers          None  1960
# 3       4               Running Bear       Johnny Preston          None  1960
# 4       5                 Teen Angel         Mark Dinning          None  1960
# ...   ...                        ...                  ...           ...   ...
# 6096   96      More Than My Hometown        Morgan Wallen          None  2020
# 6097   97              Lovin' on You           Luke Combs          None  2020
# 6098   98                   Said Sum         Moneybagg Yo          None  2020
# 6099   99                      Slide               H.E.R.            YG  2020
# 6100  100               Walk Em Down           NLE Choppa   Roddy Ricch  2020
#
#                   Spotify id  Popularity
# 0     6zwvB879PJSpTyFcg2wwnL        57.0
# 1     7dDE59NX0n466e705E8Itz        18.0
# 2     1MA9StLzlFftLbuqOmoWij        52.0
# 3     1RYznli2VNO7FCbW1Hq4KM        39.0
# 4     36NPEs4S7ik50NrlzaqoIJ        31.0
# ...                      ...         ...
# 6096  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099                     NaN         NaN
# 6100                     NaN         NaN
#
# [6101 rows x 7 columns]

# %%
track_ids, popularities = get_spotify_data(music_data)
music_data['Spotify id'] = track_ids
music_data['Popularity'] = popularities
music_data
# Out:
#      rank                      title               artist other artists  year  \
# 0       1  Theme from A Summer Place          Percy Faith          None  1960
# 1       2           He'll Have to Go           Jim Reeves          None  1960
# 2       3              Cathy's Clown  The Everly Brothers          None  1960
# 3       4               Running Bear       Johnny Preston          None  1960
# 4       5                 Teen Angel         Mark Dinning          None  1960
# ...   ...                        ...                  ...           ...   ...
# 6096   96      More Than My Hometown        Morgan Wallen          None  2020
# 6097   97              Lovin' on You           Luke Combs          None  2020
# 6098   98                   Said Sum         Moneybagg Yo          None  2020
# 6099   99                      Slide               H.E.R.            YG  2020
# 6100  100               Walk Em Down           NLE Choppa   Roddy Ricch  2020
#
#                   Spotify id  Popularity
# 0     6zwvB879PJSpTyFcg2wwnL        57.0
# 1     7dDE59NX0n466e705E8Itz        18.0
# 2     1MA9StLzlFftLbuqOmoWij        52.0
# 3     1RYznli2VNO7FCbW1Hq4KM        39.0
# 4     36NPEs4S7ik50NrlzaqoIJ        31.0
# ...                      ...         ...
# 6096  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099  2rTnVB1bvwxHtaIl4uVu7f        77.0
# 6100  4cSSL3YafYjM3yjgFO1vJg        80.0
#
# [6101 rows x 7 columns]

# %%
music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6101 entries, 0 to 6100
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           6101 non-null   object
#  1   title          6101 non-null   object
#  2   artist         6101 non-null   object
#  3   other artists  6101 non-null   object
#  4   year           6101 non-null   int64
#  5   Spotify id     5690 non-null   object
#  6   Popularity     5690 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 333.8+ KB

# %%
music_data['Spotify id'].isnull().sum()
# Out:
# 411

# %% [markdown]
# We dropped the amount of null values from 1151 to 411. At this point, there's nothing else we can do with python to extract the remaining Spotify ids, so the rest must be done manually.
#
# We will save the data frame as a csv file so we can add the Spotify ids manually in Excel.

# %%
music_data.to_csv('spotify_ids.csv')

# %% [markdown]
# After manually inserting Spotify ids and doing some cleaning in Excel, we import the csv file.

# %%
new_music_data = pd.read_csv('spotify_ids.csv', encoding='ISO-8859-1')

# %%
new_music_data
# Out:
#       Unnamed: 0 rank                      title               artist  \
# 0              0    1  Theme from A Summer Place          Percy Faith
# 1              1    2           He'll Have to Go           Jim Reeves
# 2              2    3              Cathy's Clown  The Everly Brothers
# 3              3    4               Running Bear       Johnny Preston
# 4              4    5                 Teen Angel         Mark Dinning
# ...          ...  ...                        ...                  ...
# 6096        6096   96      More Than My Hometown        Morgan Wallen
# 6097        6097   97              Lovin' on You           Luke Combs
# 6098        6098   98                   Said Sum         Moneybagg Yo
# 6099        6099   99                      Slide               H.E.R.
# 6100        6100  100               Walk Em Down           NLE Choppa
#
#      other artists  year              Spotify id  Popularity  \
# 0             None  1960  6zwvB879PJSpTyFcg2wwnL        57.0
# 1             None  1960  7dDE59NX0n466e705E8Itz        18.0
# 2             None  1960  1MA9StLzlFftLbuqOmoWij        52.0
# 3             None  1960  1RYznli2VNO7FCbW1Hq4KM        39.0
# 4             None  1960  36NPEs4S7ik50NrlzaqoIJ        31.0
# ...            ...   ...                     ...         ...
# 6096          None  2020  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097          None  2020  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098          None  2020  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099            YG  2020  2rTnVB1bvwxHtaIl4uVu7f        77.0
# 6100   Roddy Ricch  2020  4cSSL3YafYjM3yjgFO1vJg        80.0
#
#                 Spotify id.1
# 0     6zwvB879PJSpTyFcg2wwnL
# 1     7dDE59NX0n466e705E8Itz
# 2     1MA9StLzlFftLbuqOmoWij
# 3     1RYznli2VNO7FCbW1Hq4KM
# 4     36NPEs4S7ik50NrlzaqoIJ
# ...                      ...
# 6096  0eBXyY4SatzpE7opnzgXvz
# 6097  0nYvjcSlCgjcwogQAwIwNp
# 6098  3sKz6Sd72K0ofPWcJPPk6H
# 6099  2rTnVB1bvwxHtaIl4uVu7f
# 6100  4cSSL3YafYjM3yjgFO1vJg
#
# [6101 rows x 9 columns]

# %%
new_music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6101 entries, 0 to 6100
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     6101 non-null   int64
#  1   rank           6101 non-null   object
#  2   title          6101 non-null   object
#  3   artist         6101 non-null   object
#  4   other artists  6101 non-null   object
#  5   year           6101 non-null   int64
#  6   Spotify id     6098 non-null   object
#  7   Popularity     5690 non-null   float64
#  8   Spotify id.1   6098 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 429.1+ KB

# %%
new_music_data.isnull().sum()
# Out:
# Unnamed: 0         0
# rank               0
# title              0
# artist             0
# other artists      0
# year               0
# Spotify id         3
# Popularity       411
# Spotify id.1       3
# dtype: int64

# %%
new_music_data[new_music_data["Spotify id"].isnull()]
# Out:
#       Unnamed: 0 rank                       title           artist  \
# 2182        2182   82           It's Now or Never   John Schneider
# 2297        2297   97                  Goin' Down      Greg Guidry
# 3772        3772   72  ESPN Presents The Jock Jam  Various Artists
#
#      other artists  year Spotify id  Popularity Spotify id.1
# 2182          None  1981        NaN         NaN          NaN
# 2297          None  1982        NaN         NaN          NaN
# 3772          None  1997        NaN         NaN          NaN

# %% [markdown]
# There are still 3 Spotify ids that are missing. Since these are just a very small portion of our entire dataset, it should be okay to just drop these rows.

# %%
new_music_data = new_music_data.drop([new_music_data.index[2182],
                                      new_music_data.index[2297],
                                      new_music_data.index[3772]])

# %%
new_music_data
# Out:
#       Unnamed: 0 rank                      title               artist  \
# 0              0    1  Theme from A Summer Place          Percy Faith
# 1              1    2           He'll Have to Go           Jim Reeves
# 2              2    3              Cathy's Clown  The Everly Brothers
# 3              3    4               Running Bear       Johnny Preston
# 4              4    5                 Teen Angel         Mark Dinning
# ...          ...  ...                        ...                  ...
# 6096        6096   96      More Than My Hometown        Morgan Wallen
# 6097        6097   97              Lovin' on You           Luke Combs
# 6098        6098   98                   Said Sum         Moneybagg Yo
# 6099        6099   99                      Slide               H.E.R.
# 6100        6100  100               Walk Em Down           NLE Choppa
#
#      other artists  year              Spotify id  Popularity  \
# 0             None  1960  6zwvB879PJSpTyFcg2wwnL        57.0
# 1             None  1960  7dDE59NX0n466e705E8Itz        18.0
# 2             None  1960  1MA9StLzlFftLbuqOmoWij        52.0
# 3             None  1960  1RYznli2VNO7FCbW1Hq4KM        39.0
# 4             None  1960  36NPEs4S7ik50NrlzaqoIJ        31.0
# ...            ...   ...                     ...         ...
# 6096          None  2020  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097          None  2020  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098          None  2020  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099            YG  2020  2rTnVB1bvwxHtaIl4uVu7f        77.0
# 6100   Roddy Ricch  2020  4cSSL3YafYjM3yjgFO1vJg        80.0
#
#                 Spotify id.1
# 0     6zwvB879PJSpTyFcg2wwnL
# 1     7dDE59NX0n466e705E8Itz
# 2     1MA9StLzlFftLbuqOmoWij
# 3     1RYznli2VNO7FCbW1Hq4KM
# 4     36NPEs4S7ik50NrlzaqoIJ
# ...                      ...
# 6096  0eBXyY4SatzpE7opnzgXvz
# 6097  0nYvjcSlCgjcwogQAwIwNp
# 6098  3sKz6Sd72K0ofPWcJPPk6H
# 6099  2rTnVB1bvwxHtaIl4uVu7f
# 6100  4cSSL3YafYjM3yjgFO1vJg
#
# [6098 rows x 9 columns]

# %% [markdown]
# After dropping the 3 rows, we now have no more rows with missing Spotify ids. We just need to deal with missing Popularity information.

# %%
new_music_data.isnull().sum()
# Out:
# Unnamed: 0         0
# rank               0
# title              0
# artist             0
# other artists      0
# year               0
# Spotify id         0
# Popularity       408
# Spotify id.1       0
# dtype: int64

# %% [markdown]
# Let's clean the columns with our new dataframe.

# %%
# Drop index column, as well as the old spotify id column
new_music_data = new_music_data.drop(['Unnamed: 0', 'Spotify id'], axis=1)

# Rename column
new_music_data = new_music_data.rename(columns={'Spotify id.1': 'Spotify id'})

# Reorder columns
new_music_data = new_music_data[['rank', 'title', 'artist', 'other artists', 'year', 'Spotify id', 'Popularity']]

# %%
new_music_data
# Out:
#      rank                      title               artist other artists  year  \
# 0       1  Theme from A Summer Place          Percy Faith          None  1960
# 1       2           He'll Have to Go           Jim Reeves          None  1960
# 2       3              Cathy's Clown  The Everly Brothers          None  1960
# 3       4               Running Bear       Johnny Preston          None  1960
# 4       5                 Teen Angel         Mark Dinning          None  1960
# ...   ...                        ...                  ...           ...   ...
# 6096   96      More Than My Hometown        Morgan Wallen          None  2020
# 6097   97              Lovin' on You           Luke Combs          None  2020
# 6098   98                   Said Sum         Moneybagg Yo          None  2020
# 6099   99                      Slide               H.E.R.            YG  2020
# 6100  100               Walk Em Down           NLE Choppa   Roddy Ricch  2020
#
#                   Spotify id  Popularity
# 0     6zwvB879PJSpTyFcg2wwnL        57.0
# 1     7dDE59NX0n466e705E8Itz        18.0
# 2     1MA9StLzlFftLbuqOmoWij        52.0
# 3     1RYznli2VNO7FCbW1Hq4KM        39.0
# 4     36NPEs4S7ik50NrlzaqoIJ        31.0
# ...                      ...         ...
# 6096  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099  2rTnVB1bvwxHtaIl4uVu7f        77.0
# 6100  4cSSL3YafYjM3yjgFO1vJg        80.0
#
# [6098 rows x 7 columns]

# %%
artist_list = []
feat_artist_list = []

def split_artists(dataframe):
    '''
    Check if the artist column has featured artists, then split artists into lists
    '''
    for index, row in dataframe.iterrows():
        if(row['other artists'] == "None"):
            artist_list.append(row['artist'].replace(" & ", "_").replace(" featuring ","_").replace(" and ","_").replace(", ","_").replace(" with ","_").split("_")[0])
            
            #there may or not be a featured artist, so check if this is true
            try:
                feat_artist_list.append(row['artist'].replace(" & ", "_").replace(" featuring ","_").replace(" and ","_").replace(", ","_").replace(" with ","_").split("_")[1])
            except:
                feat_artist_list.append("None")
        else:
            artist_list.append(row['artist'])
            feat_artist_list.append(row['other artists'])

# %%
split_artists(new_music_data)

# %%
new_music_data["artist"] = artist_list
new_music_data["other artists"] = feat_artist_list

# %%
new_music_data
# Out:
#      rank                      title               artist other artists  year  \
# 0       1  Theme from A Summer Place          Percy Faith          None  1960
# 1       2           He'll Have to Go           Jim Reeves          None  1960
# 2       3              Cathy's Clown  The Everly Brothers          None  1960
# 3       4               Running Bear       Johnny Preston          None  1960
# 4       5                 Teen Angel         Mark Dinning          None  1960
# ...   ...                        ...                  ...           ...   ...
# 6096   96      More Than My Hometown        Morgan Wallen          None  2020
# 6097   97              Lovin' on You           Luke Combs          None  2020
# 6098   98                   Said Sum         Moneybagg Yo          None  2020
# 6099   99                      Slide               H.E.R.            YG  2020
# 6100  100               Walk Em Down           NLE Choppa   Roddy Ricch  2020
#
#                   Spotify id  Popularity
# 0     6zwvB879PJSpTyFcg2wwnL        57.0
# 1     7dDE59NX0n466e705E8Itz        18.0
# 2     1MA9StLzlFftLbuqOmoWij        52.0
# 3     1RYznli2VNO7FCbW1Hq4KM        39.0
# 4     36NPEs4S7ik50NrlzaqoIJ        31.0
# ...                      ...         ...
# 6096  0eBXyY4SatzpE7opnzgXvz        83.0
# 6097  0nYvjcSlCgjcwogQAwIwNp        76.0
# 6098  3sKz6Sd72K0ofPWcJPPk6H        75.0
# 6099  2rTnVB1bvwxHtaIl4uVu7f        77.0
# 6100  4cSSL3YafYjM3yjgFO1vJg        80.0
#
# [6098 rows x 7 columns]

# %%
new_music_data.isnull().sum()
# Out:
# rank               0
# title              0
# artist             0
# other artists      0
# year               0
# Spotify id         0
# Popularity       408
# dtype: int64

# %%
track_ids, popularities = get_spotify_data(new_music_data)
new_music_data['Popularity'] = popularities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a17af4f5556d> in <module>
# ----> 1 track_ids, popularities = get_spotify_data(new_music_data)
#       2 new_music_data['Popularity'] = popularities
#
# NameError: name 'get_spotify_data' is not defined

# %%
def get_spotify_data(dataframe):
    """
    Takes a dataframe as input.
    Returns a list of popularity scores from the Spotify API. 
    """
    from numpy import nan # we import np.nan to handle empty queries 
    popularities = []
    for id_ in list(zip(dataframe['Spotify id'])):
        try:
            print("uri:spotify:track:" + id_[0])
            #song_data = sp.search(q="uri:spotify:track: " + id_[0], type='track')
            #popularity = song_data['tracks']['items'][0]['popularity']
            popularities.append(popularity)
        except:
            print("Error in popularity extraction.")
            break
    return popularities

popularities = get_spotify_data(new_music_data)
#new_music_data['Popularity'] = popularities
# Out:
# uri:spotify:track:6zwvB879PJSpTyFcg2wwnL
# Error in popularity extraction.

# %%
popularities
# Out:
# []

# %%
new_music_data.loc[0]["Spotify id"]
# Out:
# '6zwvB879PJSpTyFcg2wwnL'

# %%
popularity = []
for id_ in new_music_data['Spotify id']:
    feature = sp.track(id_)
    features_2.append(feature)
    break

# %%
features_2[0]['popularity']
# Out:
# 57
